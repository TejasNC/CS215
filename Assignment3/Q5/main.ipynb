# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('cs-215-assignment-3-multiple-variate-regression/train.csv')
train.drop(columns=['id', 'Row#'], inplace=True)
train
# Out:
#        clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0           25.0      0.50     0.25     0.75   0.63              94.6
# 1           12.5      0.25     0.25     0.25   0.25              77.4
# 2           25.0      0.50     0.25     0.38   0.75              94.6
# 3           12.5      0.25     0.25     0.75   0.75              94.6
# 4           12.5      0.25     0.25     0.50   0.63              77.4
# ...          ...       ...      ...      ...    ...               ...
# 14995       12.5      0.25     0.25     0.50   0.63              69.7
# 14996       12.5      0.25     0.25     0.38   0.63              77.4
# 14997       12.5      0.25     0.25     0.75   0.50              77.4
# 14998       25.0      0.50     0.38     0.38   0.75              86.0
# 14999       12.5      0.25     0.25     0.50   0.75              86.0
#
#        MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 0                  57.2                  79.0              68.2
# 1                  46.8                  64.7              55.8
# 2                  57.2                  79.0              68.2
# 3                  57.2                  79.0              68.2
# 4                  46.8                  64.7              55.8
# ...                 ...                   ...               ...
# 14995              42.1                  58.2              50.2
# 14996              46.8                  64.7              55.8
# 14997              46.8                  64.7              55.8
# 14998              52.0                  71.9              62.0
# 14999              52.0                  71.9              62.0
#
#        MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# 0                  33.0                  55.9         34.0
# 1                  27.0                  45.8         34.0
# 2                  33.0                  55.9         24.0
# 3                  33.0                  55.9         16.0
# 4                  27.0                  45.8         24.0
# ...                 ...                   ...          ...
# 14995              24.3                  41.2         34.0
# 14996              27.0                  45.8         34.0
# 14997              27.0                  45.8         16.0
# 14998              30.0                  50.8          1.0
# 14999              30.0                  50.8          1.0
#
#        AverageRainingDays  fruitset  fruitmass      seeds       yield
# 0                    0.56  0.402948   0.409261  31.274591  4418.44126
# 1                    0.56  0.500438   0.445494  34.467567  5862.80545
# 2                    0.39  0.509001   0.459421  36.624966  6079.08526
# 3                    0.26  0.583379   0.498056  40.865478  7400.77538
# 4                    0.39  0.447669   0.423764  33.298861  4858.24073
# ...                   ...       ...        ...        ...         ...
# 14995                0.56  0.335927   0.352186  28.793440  3182.69865
# 14996                0.56  0.545095   0.470719  38.042756  5862.80545
# 14997                0.26  0.481801   0.442535  35.414082  5569.13925
# 14998                0.10  0.552359   0.470847  38.625436  6795.88187
# 14999                0.10  0.523846   0.464067  37.758138  6526.98819
#
# [15000 rows x 17 columns]

# %%
from fasteda import fast_eda
fast_eda(train)
# Out:
# DataFrame Head:
#    clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0       25.0      0.50     0.25     0.75   0.63              94.6
# 1       12.5      0.25     0.25     0.25   0.25              77.4
# 2       25.0      0.50     0.25     0.38   0.75              94.6
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              57.2                  79.0              68.2              33.0
# 1              46.8                  64.7              55.8              27.0
# 2              57.2                  79.0              68.2              33.0
#
#    AverageOfLowerTRange  RainingDays  AverageRainingDays  fruitset  fruitmass  \
# 0                  55.9         34.0                0.56  0.402948   0.409261
# 1                  45.8         34.0                0.56  0.500438   0.445494
# 2                  55.9         24.0                0.39  0.509001   0.459421
#
#        seeds       yield
# 0  31.274591  4418.44126
# 1  34.467567  5862.80545
# 2  36.624966  6079.08526
# DataFrame Tail:
#        clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 14997       12.5      0.25     0.25     0.75   0.50              77.4
# 14998       25.0      0.50     0.38     0.38   0.75              86.0
# 14999       12.5      0.25     0.25     0.50   0.75              86.0
#
#        MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 14997              46.8                  64.7              55.8
# 14998              52.0                  71.9              62.0
# 14999              52.0                  71.9              62.0
#
#        MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# 14997              27.0                  45.8         16.0
# 14998              30.0                  50.8          1.0
# 14999              30.0                  50.8          1.0
#
#        AverageRainingDays  fruitset  fruitmass      seeds       yield
# 14997                0.26  0.481801   0.442535  35.414082  5569.13925
# 14998                0.10  0.552359   0.470847  38.625436  6795.88187
# 14999                0.10  0.523846   0.464067  37.758138  6526.98819
# ----------------------------------------------------------------------------------------------------
# Missing values:
# <style type="text/css">
# </style>
# <table id="T_32d35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32d35_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# Shape of DataFrame:
#
# (15000, 17)
#
# ----------------------------------------------------------------------------------------------------
# DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   clonesize             15000 non-null  float64
#  1   honeybee              15000 non-null  float64
#  2   bumbles               15000 non-null  float64
#  3   andrena               15000 non-null  float64
#  4   osmia                 15000 non-null  float64
#  5   MaxOfUpperTRange      15000 non-null  float64
#  6   MinOfUpperTRange      15000 non-null  float64
#  7   AverageOfUpperTRange  15000 non-null  float64
#  8   MaxOfLowerTRange      15000 non-null  float64
#  9   MinOfLowerTRange      15000 non-null  float64
#  10  AverageOfLowerTRange  15000 non-null  float64
#  11  RainingDays           15000 non-null  float64
#  12  AverageRainingDays    15000 non-null  float64
#  13  fruitset              15000 non-null  float64
#  14  fruitmass             15000 non-null  float64
#  15  seeds                 15000 non-null  float64
#  16  yield                 15000 non-null  float64
# dtypes: float64(17)
# memory usage: 1.9 MB
# ----------------------------------------------------------------------------------------------------
# Describe DataFrame:
# /home/avinashc/.local/lib/python3.12/site-packages/fasteda/__init__.py:86: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   full_info.iloc[:,:-2] = full_info.iloc[:,:-2].applymap(lambda x: format(x, '.3f') \
# /home/avinashc/.local/lib/python3.12/site-packages/fasteda/__init__.py:92: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(color_negative_red, subset = info_cols)
# <style type="text/css">
# #T_0c387_row0_col0, #T_0c387_row0_col1, #T_0c387_row0_col5, #T_0c387_row0_col7, #T_0c387_row1_col0, #T_0c387_row1_col1, #T_0c387_row1_col2, #T_0c387_row1_col3, #T_0c387_row1_col4, #T_0c387_row1_col5, #T_0c387_row1_col6, #T_0c387_row1_col7, #T_0c387_row1_col8, #T_0c387_row2_col0, #T_0c387_row2_col1, #T_0c387_row2_col2, #T_0c387_row2_col3, #T_0c387_row2_col4, #T_0c387_row2_col5, #T_0c387_row2_col6, #T_0c387_row2_col7, #T_0c387_row2_col8, #T_0c387_row3_col0, #T_0c387_row3_col1, #T_0c387_row3_col2, #T_0c387_row3_col3, #T_0c387_row3_col4, #T_0c387_row3_col5, #T_0c387_row3_col6, #T_0c387_row3_col7, #T_0c387_row3_col8, #T_0c387_row4_col0, #T_0c387_row4_col1, #T_0c387_row4_col2, #T_0c387_row4_col3, #T_0c387_row4_col4, #T_0c387_row4_col5, #T_0c387_row4_col6, #T_0c387_row4_col7, #T_0c387_row4_col8, #T_0c387_row5_col0, #T_0c387_row6_col0, #T_0c387_row7_col0, #T_0c387_row8_col0, #T_0c387_row9_col0, #T_0c387_row9_col3, #T_0c387_row9_col8, #T_0c387_row10_col0, #T_0c387_row11_col0, #T_0c387_row11_col1, #T_0c387_row11_col2, #T_0c387_row11_col4, #T_0c387_row11_col5, #T_0c387_row11_col6, #T_0c387_row11_col7, #T_0c387_row11_col8, #T_0c387_row12_col0, #T_0c387_row12_col1, #T_0c387_row12_col2, #T_0c387_row12_col3, #T_0c387_row12_col4, #T_0c387_row12_col5, #T_0c387_row12_col6, #T_0c387_row12_col7, #T_0c387_row12_col8, #T_0c387_row13_col0, #T_0c387_row13_col1, #T_0c387_row13_col2, #T_0c387_row13_col3, #T_0c387_row13_col4, #T_0c387_row13_col5, #T_0c387_row13_col6, #T_0c387_row13_col7, #T_0c387_row13_col8, #T_0c387_row14_col0, #T_0c387_row14_col1, #T_0c387_row14_col2, #T_0c387_row14_col3, #T_0c387_row14_col4, #T_0c387_row14_col5, #T_0c387_row14_col6, #T_0c387_row14_col7, #T_0c387_row14_col8, #T_0c387_row15_col0, #T_0c387_row15_col3, #T_0c387_row16_col0 {
#   background-color: #9e0142;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row0_col2, #T_0c387_row0_col3, #T_0c387_row0_col4, #T_0c387_row0_col6, #T_0c387_row0_col8, #T_0c387_row5_col3, #T_0c387_row6_col3, #T_0c387_row6_col7, #T_0c387_row6_col8, #T_0c387_row7_col3, #T_0c387_row8_col3, #T_0c387_row8_col8, #T_0c387_row9_col1, #T_0c387_row9_col2, #T_0c387_row9_col5, #T_0c387_row9_col6, #T_0c387_row9_col7, #T_0c387_row10_col3, #T_0c387_row10_col7, #T_0c387_row10_col8, #T_0c387_row15_col1, #T_0c387_row15_col2, #T_0c387_row15_col5, #T_0c387_row15_col6, #T_0c387_row15_col7, #T_0c387_row15_col8 {
#   background-color: #a00343;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row0_col9, #T_0c387_row1_col9, #T_0c387_row1_col10, #T_0c387_row2_col9, #T_0c387_row3_col9, #T_0c387_row4_col10, #T_0c387_row12_col9, #T_0c387_row14_col10, #T_0c387_row15_col9 {
#   color: #00ff00;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_0c387_row0_col10, #T_0c387_row2_col10, #T_0c387_row3_col10, #T_0c387_row4_col9, #T_0c387_row5_col9, #T_0c387_row5_col10, #T_0c387_row6_col9, #T_0c387_row6_col10, #T_0c387_row7_col9, #T_0c387_row7_col10, #T_0c387_row8_col9, #T_0c387_row8_col10, #T_0c387_row9_col9, #T_0c387_row9_col10, #T_0c387_row10_col9, #T_0c387_row10_col10, #T_0c387_row11_col9, #T_0c387_row11_col10, #T_0c387_row12_col10, #T_0c387_row13_col9, #T_0c387_row13_col10, #T_0c387_row14_col9, #T_0c387_row15_col10, #T_0c387_row16_col9, #T_0c387_row16_col10 {
#   color: #ff0000;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_0c387_row5_col1, #T_0c387_row5_col2, #T_0c387_row5_col5, #T_0c387_row5_col6, #T_0c387_row5_col7, #T_0c387_row7_col5, #T_0c387_row9_col4, #T_0c387_row15_col4 {
#   background-color: #a40844;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row5_col4 {
#   background-color: #b41947;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row5_col8, #T_0c387_row6_col1, #T_0c387_row6_col2, #T_0c387_row6_col5, #T_0c387_row6_col6, #T_0c387_row7_col1, #T_0c387_row7_col2, #T_0c387_row7_col6, #T_0c387_row7_col7, #T_0c387_row7_col8, #T_0c387_row8_col1, #T_0c387_row8_col2, #T_0c387_row8_col5, #T_0c387_row8_col6, #T_0c387_row8_col7, #T_0c387_row10_col1, #T_0c387_row10_col2, #T_0c387_row10_col5, #T_0c387_row10_col6, #T_0c387_row11_col3 {
#   background-color: #a20643;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row6_col4, #T_0c387_row10_col4 {
#   background-color: #ab0f45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row7_col4 {
#   background-color: #b11747;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row8_col4 {
#   background-color: #ad1246;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0c387_row16_col1, #T_0c387_row16_col2, #T_0c387_row16_col3, #T_0c387_row16_col4, #T_0c387_row16_col5, #T_0c387_row16_col6, #T_0c387_row16_col7, #T_0c387_row16_col8 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_0c387">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c387_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_0c387_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_0c387_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_0c387_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_0c387_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_0c387_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_0c387_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_0c387_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_0c387_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_0c387_level0_col9" class="col_heading level0 col9" >skewness</th>
#       <th id="T_0c387_level0_col10" class="col_heading level0 col10" >kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c387_level0_row0" class="row_heading level0 row0" >clonesize</th>
#       <td id="T_0c387_row0_col0" class="data row0 col0" >15000</td>
#       <td id="T_0c387_row0_col1" class="data row0 col1" >19.72</td>
#       <td id="T_0c387_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_0c387_row0_col3" class="data row0 col3" >6.644</td>
#       <td id="T_0c387_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_0c387_row0_col5" class="data row0 col5" >12.5</td>
#       <td id="T_0c387_row0_col6" class="data row0 col6" >25</td>
#       <td id="T_0c387_row0_col7" class="data row0 col7" >25</td>
#       <td id="T_0c387_row0_col8" class="data row0 col8" >40</td>
#       <td id="T_0c387_row0_col9" class="data row0 col9" >0.079649</td>
#       <td id="T_0c387_row0_col10" class="data row0 col10" >-1.163640</td>
#     </tr>
#     <tr>
#       <th id="T_0c387_level0_row1" class="row_heading level0 row1" >honeybee</th>
#       <td id="T_0c387_row1_col0" class="data row1 col0" >15000</td>
#       <td id="T_0c387_row1_col1" class="data row1 col1" >0.384</td>
#       <td id="T_0c387_row1_col2" class="data row1 col2" >0.5</td>
#       <td id="T_0c387_row1_col3" class="data row1 col3" >0.261</td>
#       <td id="T_0c387_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_0c387_row1_col5" class="data row1 col5" >0.25</td>
#       <td id="T_0c387_row1_col6" class="data row1 col6" >0.5</td>
#       <td id="T_0c387_row1_col7" class="data row1 col7" >0.5</td>
#       <td id="T_0c387_row1_col8" class="data row1 col8" >18.43</td>
#       <td id="T_0c387_row1_col9" class="data row1 col9" >47.020301</td>
#       <td id="T_0c387_row1_col10" class="data row1 col10" >3127.658420</td>
#     </tr>
#     <tr>
#       <th id="T_0c387_level0_row2" class="row_heading level0 row2" >bumbles</th>
#       <td id="T_0c387_row2_col0" class="data row2 col0" >15000</td>
#       <td id="T_0c387_row2_col1" class="data row2 col1" >0.285</td>
#       <td id="T_0c387_row2_col2" class="data row2 col2" >0.25</td>
#       <td id="T_0c387_row2_col3" class="data row2 col3" >0.059</td>
#       <td id="T_0c387_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_0c387_row2_col5" class="data row2 col5" >0.25</td>
#       <td id="T_0c387_row2_col6" class="data row2 col6" >0.25</td>
#       <td id="T_0c387_row2_col7" class="data row2 col7" >0.38</td>
#       <td id="T_0c387_row2_col8" class="data row2 col
# ----------------------------------------------------------------------------------------------------
# DataFrame Correlation:
# ----------------------------------------------------------------------------------------------------
# Histogram(s) & Boxplot(s):
# ----------------------------------------------------------------------------------------------------
# Countplot(s):

# %%
test = pd.read_csv('cs-215-assignment-3-multiple-variate-regression/test.csv')
test.drop(columns=['id', 'Row#'], inplace=True)
test
# Out:
#       clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          25.0      0.50     0.25     0.38   0.63              77.4
# 1          12.5      0.25     0.25     0.63   0.63              69.7
# 2          25.0      0.25     0.25     0.25   0.25              69.7
# 3          25.0      0.50     0.38     0.38   0.63              86.0
# 4          12.5      0.25     0.25     0.38   0.25              94.6
# ...         ...       ...      ...      ...    ...               ...
# 9995       12.5      0.25     0.25     0.38   0.63              86.0
# 9996       12.5      0.25     0.25     0.63   0.50              94.6
# 9997       25.0      0.50     0.25     0.38   0.63              86.0
# 9998       12.5      0.25     0.25     0.38   0.38              94.6
# 9999       25.0      0.50     0.38     0.50   0.75              69.7
#
#       MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 0                 46.8                  64.7              55.8
# 1                 42.1                  58.2              50.2
# 2                 42.1                  58.2              50.2
# 3                 52.0                  71.9              62.0
# 4                 57.2                  79.0              68.2
# ...                ...                   ...               ...
# 9995              52.0                  71.9              62.0
# 9996              57.2                  79.0              68.2
# 9997              52.0                  71.9              62.0
# 9998              57.2                  79.0              68.2
# 9999              42.1                  58.2              50.2
#
#       MinOfLowerTRange  AverageOfLowerTRange  RainingDays  AverageRainingDays  \
# 0                 27.0                  45.8         24.0                0.39
# 1                 24.3                  41.2         16.0                0.26
# 2                 24.3                  41.2         24.0                0.39
# 3                 30.0                  50.8         24.0                0.39
# 4                 33.0                  55.9         16.0                0.26
# ...                ...                   ...          ...                 ...
# 9995              30.0                  50.8         16.0                0.26
# 9996              33.0                  55.9         34.0                0.56
# 9997              30.0                  50.8         16.0                0.26
# 9998              33.0                  55.9         16.0                0.26
# 9999              24.3                  41.2         34.0                0.56
#
#       fruitset  fruitmass      seeds
# 0     0.424574   0.417909  31.448420
# 1     0.552359   0.476308  38.417394
# 2     0.511413   0.445494  35.487008
# 3     0.520637   0.460795  37.712513
# 4     0.470593   0.438026  35.824852
# ...        ...        ...        ...
# 9995  0.608345   0.509528  42.487539
# 9996  0.362184   0.388822  29.370607
# 9997  0.589622   0.487428  40.813181
# 9998  0.593030   0.494895  41.971816
# 9999  0.388956   0.396044  29.388560
#
# [10000 rows x 16 columns]

# %%
for i in range(0, 16):
	plt.scatter(train.iloc[:, i], train.iloc[:, 16])
	plt.show()

# %%
# Standardising the data set
def standardise(data):
	# Standardising the data
	data_mean = data.mean()
	data_std = data.std()
	data = (data - data_mean) / data_std
	return data, data_mean, data_std

train_X, train_mean, train_std = standardise(train.iloc[:, 13:16])
print(train_X)
train_Y = train.iloc[:, 16]
print(train_Y)
# Out:
#        fruitset  fruitmass     seeds
# 0     -1.289173  -0.975560 -1.187064
# 1     -0.015666  -0.022115 -0.407197
# 2      0.096203   0.344337  0.119736
# 3      1.067801   1.360963  1.155457
# 4     -0.704987  -0.593930 -0.692647
# ...         ...        ...       ...
# 14995 -2.164672  -2.477390 -1.793071
# 14996  0.567692   0.641650  0.466023
# 14997 -0.259122  -0.099980 -0.176016
# 14998  0.662594   0.644999  0.608339
# 14999  0.290115   0.466595  0.396507
#
# [15000 rows x 3 columns]
# 0        4418.44126
# 1        5862.80545
# 2        6079.08526
# 3        7400.77538
# 4        4858.24073
#             ...
# 14995    3182.69865
# 14996    5862.80545
# 14997    5569.13925
# 14998    6795.88187
# 14999    6526.98819
# Name: yield, Length: 15000, dtype: float64

# %%
for i in range(0, 3):
	plt.scatter(train_X.iloc[:, i], train_Y)
	plt.show()

# %%
def fit(train_x, train_y):
	# Adding a column of ones to the train_x
	train_x = np.c_[np.ones(train_x.shape[0]), train_x]

	# Calculating the coefficients
	coefficients = np.linalg.inv(train_x.T @ train_x) @ train_x.T @ train_y
	return coefficients

coefficients = fit(train_X, train_Y).reshape(-1, 1)
print(coefficients)
print(coefficients.shape)
# Out:
# [[6033.58619724]
#  [1074.36051836]
#  [-156.31656526]
#  [ 372.11414961]]
# (4, 1)

# %%
def standardise_test(test, train_mean, train_std):
	# Standardising the data
	test = (test - train_mean) / train_std
	return test

# %%
test_X = standardise_test(test.iloc[:, 13:16], train_mean, train_std)
print(test_X)
test_X = np.c_[np.ones(test_X.shape[0]), test_X]
print(test_X)
# Out:
#       fruitset  fruitmass     seeds
# 0    -1.006673  -0.747993 -1.144607
# 1     0.662594   0.788716  0.557526
# 2     0.127710  -0.022115 -0.158204
# 3     0.248202   0.380510  0.385363
# 4    -0.405525  -0.218622 -0.075688
# ...        ...        ...       ...
# 9995  1.393933   1.662843  1.551636
# 9996 -1.821685  -1.513381 -1.652101
# 9997  1.149363   1.081310  1.142683
# 9998  1.193874   1.277809  1.425674
# 9999 -1.471953  -1.323348 -1.647716
#
# [10000 rows x 3 columns]
# [[ 1.         -1.00667322 -0.74799278 -1.14460669]
#  [ 1.          0.66259368  0.78871598  0.55752609]
#  [ 1.          0.12770974 -0.02211456 -0.15820418]
#  ...
#  [ 1.          1.14936313  1.08130992  1.14268346]
#  [ 1.          1.19387428  1.27780931  1.42567356]
#  [ 1.         -1.47195257 -1.32334803 -1.64771581]]

# %%
test_pred = test_X @ coefficients

# %%
test_pred = pd.DataFrame(test_pred, columns=['yield'])
print(test_pred)
# Out:
#             yield
# 0     4643.055557
# 1     6829.624660
# 2     6115.379359
# 3     6384.164012
# 4     5603.915827
# ...           ...
# 9995  7848.628111
# 9996  3698.235929
# 9997  7524.598594
# 9998  7647.008132
# 9999  4045.901323
#
# [10000 rows x 1 columns]

# %%
def submit(y_pred):
	test = pd.read_csv('cs-215-assignment-3-multiple-variate-regression/test.csv')
	test.drop(columns=['Row#', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia', 'MinOfUpperTRange', 'MinOfLowerTRange', 'MaxOfUpperTRange', 'MaxOfLowerTRange', 'AverageOfUpperTRange', 'AverageOfLowerTRange', 'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds'], inplace=True)
	test['yield'] = y_pred
	return test

# %%
submit(test_pred).to_csv('submission.csv', index=False)
